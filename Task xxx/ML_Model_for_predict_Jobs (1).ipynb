# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/IT_Job_Roles_Skills.csv", encoding='latin1')
print(data)
# Out:
#                                              Job Title  \
# 0                                       Admin Big Data
# 1                          Ansible Operations Engineer
# 2                            Artifactory Administrator
# 3    Artificial Intelligence / Machine Learning Leader
# 4    Artificial Intelligence / Machine Learning Sr....
# ..                                                 ...
# 488                 EFFECTS TECHNICAL DIRECTOR (FX TD)
# 489                                      LAYOUT ARTIST
# 490                                      AI RESEARCHER
# 491                              AI SOFTWARE ARCHITECT
# 492                    BUSINESS INTELLIGENCE DEVELOPER
#
#                                        Job Description  \
# 0    Responsible for managing and overseeing big da...
# 1    Focuses on automating IT processes using Ansib...
# 2    Manages the Artifactory repository for build a...
# 3    Leads AI/ML projects and teams, defining strat...
# 4    Senior role overseeing multiple AI/ML initiati...
# ..                                                 ...
# 488  Develops technical solutions for visual effect...
# 489  Creates layouts for animated scenes, determini...
# 490  Conducts research in artificial intelligence a...
# 491  Designs and implements AI software systems, en...
# 492  Develops business intelligence solutions, crea...
#
#                                                 Skills  \
# 0    Hadoop, Spark, MapReduce, Data Lakes, Data War...
# 1    Ansible, Linux, Automation, Cloud Platforms, C...
# 2    Artifactory, CI/CD, Jenkins, Docker, Maven, Gr...
# 3    AI Strategy, Machine Learning, Team Management...
# 4    AI Strategy, Machine Learning, Team Management...
# ..                                                 ...
# 488  Visual Effects, Technical Expertise, Scripting...
# 489  Layout, Cinematography, 3D Modeling, Visual St...
# 490  AI/ML Algorithms, Python, Research Methodologi...
# 491  AI/ML Architecture, Software Design, Cloud Com...
# 492  Business Intelligence Tools, Data Modeling, SQ...
#
#                                         Certifications
# 0    Cloudera Certified Professional (CCP), Hortonw...
# 1    Red Hat Certified Specialist in Ansible Automa...
# 2    JFrog Artifactory Certification, DevOps Instit...
# 3    AI-900: Microsoft Azure AI Fundamentals, Certi...
# 4    Certified Artificial Intelligence Practitioner...
# ..                                                 ...
# 488  SideFX Houdini FX Certification, Pixar's Rende...
# 489  Autodesk Maya Certified User, Concept Art Acad...
# 490  Google TensorFlow Developer Certificate, IBM A...
# 491  Microsoft Certified: Azure AI Engineer Associa...
# 492  Microsoft Certified: Power BI Data Analyst, Ta...
#
# [493 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        493 non-null    object
#  1   Job Description  493 non-null    object
#  2   Skills           493 non-null    object
#  3   Certifications   493 non-null    object
# dtypes: object(4)
# memory usage: 15.5+ KB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(lowercase=True, stop_words='english')

# %%
from re import X
df = pd.DataFrame(data)
X = vectorizer.fit_transform(df["Skills"])
y = df["Job Title"]

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(X,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (345, 565)

# %%
x_test.shape
# Out:
# (148, 565)

# %%
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
NB.fit(x_train.toarray(),y_train)
# Out:
# GaussianNB()

# %%
models = {
    "Naive Bayes":        MultinomialNB(),
    "SVM":                SVC(kernel='linear', probability=True),
    "Random Forest":      RandomForestClassifier(n_estimators=100, random_state=42),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "kNN":                KNeighborsClassifier(n_neighbors=3),
    "Decision Tree":      DecisionTreeClassifier(random_state=42),
}

# Train all models
for name, model in models.items():
    model.fit(X, y_encoded)



def predict_job(input_skills: str, top_n: int = 3):
    # TF-IDF transform
    input_vec = vectorizer.transform([input_skills])

    # --- Method 1: Cosine Similarity (baseline) ---
    similarities = cosine_similarity(input_vec, X)[0]
    top_indices = similarities.argsort()[::-1][:top_n]

    print("\n📌 METHOD 1: TF-IDF Cosine Similarity")
    print("-" * 40)
    for rank, idx in enumerate(top_indices, 1):
        score = similarities[idx] * 100
        bar = "█" * int(score / 5)
        print(f"  {rank}. {df['Job Title'][idx]}")
        print(f"     Match: {bar} {score:.1f}%")

    # --- Method 2: ML Models ---
    print("\n📌 METHOD 2: ML Model Predictions")
    print("-" * 40)

    model_results = {}
    for name, model in models.items():
        if hasattr(model, "predict_proba"):
            proba = model.predict_proba(input_vec)[0]
            top_idx = proba.argsort()[::-1][:top_n]
            results = [(le.inverse_transform([i])[0], proba[i] * 100) for i in top_idx]
        else:
            pred = model.predict(input_vec)[0]
            results = [(le.inverse_transform([pred])[0], 100.0)]

        model_results[name] = results
        top_title, top_score = results[0]
        print(f"\n  🤖 {name}:")
        for title, score in results:
            bar = "█" * int(score / 5)
            print(f"     → {title}")
            print(f"        {bar} {score:.1f}%")

    # --- Voting: Best Overall ---
    print("\n" + "=" * 60)
    print("🏆 BEST MATCH (Majority Vote)")
    print("=" * 60)

    votes = {}
    for name, results in model_results.items():
        top_title = results[0][0]
        votes[top_title] = votes.get(top_title, 0) + 1

    # Also add cosine similarity top result
    cos_top = df['Job Title'][top_indices[0]]
    votes[cos_top] = votes.get(cos_top, 0) + 1

    best = sorted(votes.items(), key=lambda x: x[1], reverse=True)
    for title, vote_count in best:
        stars = "⭐" * vote_count
        print(f"  {stars} {title} ({vote_count} votes)")

    print(f"\n  ✅ RECOMMENDED: {best[0][0]}")
    print("=" * 60)

    return best[0][0]


# ========== INTERACTIVE MODE ==========
print("\n💡 HOW TO USE:")
print("   Type your skills separated by commas")
print("   Type 'quit' to exit\n")


print("\n" + "-" * 60)
user_input = input("🎯 Enter your skills: ").strip()

if user_input.lower() in ['quit', 'exit', 'q']:
    print("\n👋 Bye!\n")


if not user_input:
    print("⚠️  Please enter at least one skill!")


result = predict_job(user_input)
# Out:
# 💡 HOW TO USE:
#    Type your skills separated by commas
#    Type 'quit' to exit
#
#
# ------------------------------------------------------------
# 🎯 Enter your skills: Hadoop, Spark, MapReduce, Data Lakes, Data Warehousing, Big Data Architecture, NoSQL, Data Modeling, ETL, Cloud Computing, AWS, Azure, Data Governance, Security
#
# 📌 METHOD 1: TF-IDF Cosine Similarity
# ----------------------------------------
#   1. Admin Big Data
#      Match: ████████████████████ 100.0%
#   2. Big Data Architect
#      Match: ██████████████████ 91.4%
#   3. Data Architect
#      Match: ███████████████ 78.1%
#
# 📌 METHOD 2: ML Model Predictions
# ----------------------------------------
#
#   🤖 Naive Bayes:
#      → DATA MODELER
#          0.7%
#      → DATA ANALYST
#          0.6%
#      → DATA SCIENTIST
#          0.6%
#
#   🤖 SVM:
#      → BUSINESS SYSTEMS ANALYST
#          0.8%
#      → INFORMATION ARCHITECT
#          0.7%
#      → PRODUCT MANAGER
#          0.7%
#
#   🤖 Random Forest:
#      → Admin Big Data
#         ███████████ 59.0%
#      → Big Data Architect
#         ███ 16.0%
#      → Data Architect
#          4.0%
#
#   🤖 Logistic Regression:
#      → DATA MODELER
#          0.8%
#      → DATA ANALYST
#          0.6%
#      → DATA SCIENTIST
#          0.6%
#
#   🤖 kNN:
#      → Data Architect
#         ██████ 33.3%
#      → Big Data Architect
#         ██████ 33.3%
#      → Admin Big Data
#         ██████ 33.3%
#
#   🤖 Decision Tree:
#      → Admin Big Data
#         ████████████████████ 100.0%
#      → DOCKER ENGINEER
#          0.0%
#      → Data Analysts
#          0.0%
#
# ============================================================
# 🏆 BEST MATCH (Majority Vote)
# ============================================================
#   ⭐⭐⭐ Admin Big Data (3 votes)
#   ⭐⭐ DATA MODELER (2 votes)
#   ⭐ BUSINESS SYSTEMS ANALYST (1 votes)
#   ⭐ Data Architect (1 votes)
#
#   ✅ RECOMMENDED: Admin Big Data
# ============================================================

# %%
import pickle

with open("job_matcher.pkl", "wb") as f:
    pickle.dump(models, f)

# %%
import pickle

# Load the models from the pickle file
with open("job_matcher.pkl", "rb") as f:
    loaded_models = pickle.load(f)

# Reassign the global 'models' variable so the predict_job function uses the loaded models
models = loaded_models

# Make a prediction using the predict_job function with sample input
sample_skills = "Team Management, Project Management, Software Development, Agile Methodologies, Budgeting, Communication, Leadership"
print(f"\nPredicting job roles for skills: {sample_skills}")
predicted_job = predict_job(sample_skills)
print(f"\nRecommended Job Role for '{sample_skills}': {predicted_job}")
# Out:
# Predicting job roles for skills: Team Management, Project Management, Software Development, Agile Methodologies, Budgeting, Communication, Leadership
#
# 📌 METHOD 1: TF-IDF Cosine Similarity
# ----------------------------------------
#   1. Director of Engineering
#      Match: ████████████████████ 100.0%
#   2. DIRECTOR OF ENGINEERING
#      Match: █████████████ 70.0%
#   3. IT MANAGER
#      Match: █████████████ 69.4%
#
# 📌 METHOD 2: ML Model Predictions
# ----------------------------------------
#
#   🤖 Naive Bayes:
#      → TECHNICAL LEAD
#          0.8%
#      → DEVOPS MANAGER
#          0.8%
#      → AGILE PROJECT MANAGER
#          0.8%
#
#   🤖 SVM:
#      → BUSINESS SYSTEMS ANALYST
#          0.8%
#      → AGILE PROJECT MANAGER
#          0.7%
#      → INFORMATION ARCHITECT
#          0.7%
#
#   🤖 Random Forest:
#      → Director of Engineering
#         ████████████ 64.0%
#      → TECHNICAL LEAD
#         █ 6.0%
#      → ITERATION MANAGER
#         █ 5.0%
#
#   🤖 Logistic Regression:
#      → TECHNICAL LEAD
#          0.9%
#      → AGILE PROJECT MANAGER
#          0.9%
#      → DEVOPS MANAGER
#          0.8%
#
#   🤖 kNN:
#      → DIRECTOR OF ENGINEERING
#         ██████ 33.3%
#      → IT MANAGER
#         ██████ 33.3%
#      → Director of Engineering
#         ██████ 33.3%
#
#   🤖 Decision Tree:
#      → Director of Engineering
#         ████████████████████ 100.0%
#      → DOCKER ENGINEER
#          0.0%
#      → Data Analysts
#          0.0%
#
# ============================================================
# 🏆 BEST MATCH (Majority Vote)
# ============================================================
#   ⭐⭐⭐ Director of Engineering (3 votes)
#   ⭐⭐ TECHNICAL LEAD (2 votes)
#   ⭐ BUSINESS SYSTEMS ANALYST (1 votes)
#   ⭐ DIRECTOR OF ENGINEERING (1 votes)
#
#   ✅ RECOMMENDED: Director of Engineering
# ============================================================
#
# Recommended Job Role for 'Team Management, Project Management, Software Development, Agile Methodologies, Budgeting, Communication, Leadership': Director of Engineering
